# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Loading

# %%
df = pd.read_csv('Cleaned_Laptop_data.csv')

# %%
df
# Out:
#       brand     model processor_brand     processor_Name processor_gnrtn  \
# 0      ASUS   Celeron           Intel                  5         Missing
# 1      ASUS  VivoBook           Intel                  5            10th
# 2      ASUS  Vivobook           Intel  A6-9225 Processor            10th
# 3        HP      Core           Intel           APU Dual            11th
# 4        HP      Core           Intel           APU Dual            11th
# ..      ...       ...             ...                ...             ...
# 840    DELL  Inspiron             AMD            Ryzen 9         Missing
# 841      HP  Pavilion             AMD            Ryzen 9         Missing
# 842    ASUS   EeeBook           Intel            Ryzen 9         Missing
# 843      HP  Pavilion             AMD           Slot for         Missing
# 844  Lenovo   Ideapad           Intel      Snapdragon 7c            10th
#
#      ram_gb     Apps  ssd   hdd       os  os_bit  graphic_card_gb      weight  \
# ...

# %% [markdown]
# ### Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845 entries, 0 to 844
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            845 non-null    object
#  1   model            845 non-null    object
#  2   processor_brand  845 non-null    object
#  3   processor_Name   845 non-null    object
#  4   processor_gnrtn  845 non-null    object
#  5   ram_gb           845 non-null    float64
#  6   Apps             845 non-null    object
#  7   ssd              845 non-null    int64
#  8   hdd              845 non-null    int64
#  9   os               845 non-null    object
#  10  os_bit           845 non-null    int64
#  11  graphic_card_gb  845 non-null    int64
#  12  weight           845 non-null    object
#  13  display_size     845 non-null    object
#  14  warranty         845 non-null    int64
#  15  Touchscreen      845 non-null    object
#  16  msoffice         845 non-null    object
# ...

# %% [markdown]
# ### Checking missing data

# %%
df.isnull().sum()
# Out:
# brand              0
# model              0
# processor_brand    0
# processor_Name     0
# processor_gnrtn    0
# ram_gb             0
# Apps               0
# ssd                0
# hdd                0
# os                 0
# os_bit             0
# graphic_card_gb    0
# weight             0
# display_size       0
# warranty           0
# Touchscreen        0
# msoffice           0
# Price              3
# dtype: int64

# %%
df[df['Price'].isnull()]
# Out:
#    brand     model processor_brand     processor_Name processor_gnrtn  ram_gb  \
# 2   ASUS  Vivobook           Intel  A6-9225 Processor            10th     4.0
# 26  DELL  Inspiron           Intel       Celeron Dual            11th     4.0
# 64    HP  Pavilion             AMD            Core i3         Missing     4.0
#
#     Apps  ssd   hdd       os  os_bit  graphic_card_gb  weight display_size  \
# 2   DDR3    0  1024  Windows      64                0  Casual         14.1
# 26  DDR4  256  1024  Windows      64                0  Casual         15.6
# 64  DDR4  256  1024  Windows      64                4  Gaming         15.6
#
#     warranty Touchscreen msoffice  Price
# 2          1          No       No    NaN
# 26         0          No       No    NaN
# 64         1          No      Yes    NaN

# %% [markdown]
# ### Missing Data Treatment

# %%
df[(df['brand']=='ASUS') & (df['model']=='Vivobook') 
   & (df['processor_brand']=='Intel') & (df['ram_gb']==4.0)& (df['hdd']==1024)].mean()['Price']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16164\42034011.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   & (df['processor_brand']=='Intel') & (df['ram_gb']==4.0)& (df['hdd']==1024)].mean()['Price']
# 55990.0

# %%
df.loc[(df['brand']=='ASUS')& (df['Price'].isnull()), ['Price']]=55990.0

# %%
df[(df['brand']=='DELL') & (df['model']=='Inspiron') 
   & (df['processor_brand']=='Intel') & (df['ram_gb']==4.0)& (df['hdd']==1024)].mean()['Price']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16164\1264565075.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   & (df['processor_brand']=='Intel') & (df['ram_gb']==4.0)& (df['hdd']==1024)].mean()['Price']
# 42490.0

# %%
df.loc[(df['brand']=='DELL')& (df['Price'].isnull()), ['Price']]=42490.0

# %%
df[(df['brand']=='HP') & (df['model']=='Pavilion') 
   & (df['processor_brand']=='AMD') & (df['ram_gb']==4.0)].mean()['Price']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16164\2929580619.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   & (df['processor_brand']=='AMD') & (df['ram_gb']==4.0)].mean()['Price']
# 57990.0

# %%
df.loc[(df['brand']=='HP')& (df['Price'].isnull()), ['Price']]=57990.0

# %% [markdown]
# ### Checking missing data

# %%
df[df['Price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [brand, model, processor_brand, processor_Name, processor_gnrtn, ram_gb, Apps, ssd, hdd, os, os_bit, graphic_card_gb, weight, display_size, warranty, Touchscreen, msoffice, Price]
# Index: []

# %%
df.shape
# Out:
# (845, 18)

# %% [markdown]
# ### Duplicate Checking

# %%
df[df.duplicated()]
# Out:
#      brand     model processor_brand processor_Name processor_gnrtn  ram_gb  \
# 85    ASUS  VivoBook             AMD        Core i3         Missing     4.0
# 94    ASUS  VivoBook           Intel        Core i3            11th     4.0
# 276   ASUS  VivoBook           Intel        Core i5            11th     8.0
# 278     HP  Pavilion           Intel        Core i5            11th     8.0
# 296  APPLE      2021           Apple        Core i5         Missing     8.0
# 313   ASUS   Pentium           Intel        Core i5         Missing     8.0
# 336  APPLE   MacBook           Intel        Core i5            10th     8.0
# 389   ASUS  VivoBook             AMD        Core i5         Missing     8.0
# 830  Avita     Liber           Intel        Ryzen 9             7th    16.0
#
#         Apps   ssd   hdd       os  os_bit  graphic_card_gb      weight  \
# 85      DDR4   256  1024  Windows      64                0      Casual
# ...

# %%
df.loc[df.duplicated(keep='first')]
# Out:
#      brand     model processor_brand processor_Name processor_gnrtn  ram_gb  \
# 85    ASUS  VivoBook             AMD        Core i3         Missing     4.0
# 94    ASUS  VivoBook           Intel        Core i3            11th     4.0
# 276   ASUS  VivoBook           Intel        Core i5            11th     8.0
# 278     HP  Pavilion           Intel        Core i5            11th     8.0
# 296  APPLE      2021           Apple        Core i5         Missing     8.0
# 313   ASUS   Pentium           Intel        Core i5         Missing     8.0
# 336  APPLE   MacBook           Intel        Core i5            10th     8.0
# 389   ASUS  VivoBook             AMD        Core i5         Missing     8.0
# 830  Avita     Liber           Intel        Ryzen 9             7th    16.0
#
#         Apps   ssd   hdd       os  os_bit  graphic_card_gb      weight  \
# 85      DDR4   256  1024  Windows      64                0      Casual
# ...

# %% [markdown]
# ### Duplicate Removing

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df.shape
# Out:
# (836, 18)

# %% [markdown]
# ### Data Visualization

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df['brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['processor_brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['processor_brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Checking Correlation between target and other column

# %%
df.corr()['Price']
# Out:
# ram_gb             0.128258
# ssd                0.524946
# hdd               -0.211992
# os_bit            -0.069523
# graphic_card_gb    0.482795
# warranty           0.026203
# Price              1.000000
# Name: Price, dtype: float64

# %%
df
# Out:
#       brand     model processor_brand     processor_Name processor_gnrtn  \
# 0      ASUS   Celeron           Intel                  5         Missing
# 1      ASUS  VivoBook           Intel                  5            10th
# 2      ASUS  Vivobook           Intel  A6-9225 Processor            10th
# 3        HP      Core           Intel           APU Dual            11th
# 4        HP      Core           Intel           APU Dual            11th
# ..      ...       ...             ...                ...             ...
# 840    DELL  Inspiron             AMD            Ryzen 9         Missing
# 841      HP  Pavilion             AMD            Ryzen 9         Missing
# 842    ASUS   EeeBook           Intel            Ryzen 9         Missing
# 843      HP  Pavilion             AMD           Slot for         Missing
# 844  Lenovo   Ideapad           Intel      Snapdragon 7c            10th
#
#      ram_gb     Apps  ssd   hdd       os  os_bit  graphic_card_gb      weight  \
# ...

# %% [markdown]
# ### Features and target separation

# %%
X = df.drop(columns=['Price'])
y = df['Price']

# %%
X
# Out:
#       brand     model processor_brand     processor_Name processor_gnrtn  \
# 0      ASUS   Celeron           Intel                  5         Missing
# 1      ASUS  VivoBook           Intel                  5            10th
# 2      ASUS  Vivobook           Intel  A6-9225 Processor            10th
# 3        HP      Core           Intel           APU Dual            11th
# 4        HP      Core           Intel           APU Dual            11th
# ..      ...       ...             ...                ...             ...
# 840    DELL  Inspiron             AMD            Ryzen 9         Missing
# 841      HP  Pavilion             AMD            Ryzen 9         Missing
# 842    ASUS   EeeBook           Intel            Ryzen 9         Missing
# 843      HP  Pavilion             AMD           Slot for         Missing
# 844  Lenovo   Ideapad           Intel      Snapdragon 7c            10th
#
#      ram_gb     Apps  ssd   hdd       os  os_bit  graphic_card_gb      weight  \
# ...

# %%
y
# Out:
# 0      23990.0
# 1      37990.0
# 2      55990.0
# 3      54990.0
# 4      54990.0
#         ...
# 840    42090.0
# 841    64990.0
# 842    22990.0
# 843    79990.0
# 844    86999.0
# Name: Price, Length: 836, dtype: float64

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
X = X.apply(encoder.fit_transform)

# %%
X
# Out:
#      brand  model  processor_brand  processor_Name  processor_gnrtn  ram_gb  \
# 0        2     24                4               0                7       0
# 1        2    103                4               0                0       0
# 2        2    104                4               1                0       0
# 3        5     29                4               2                1       0
# 4        5     29                4               2                1       0
# ..     ...    ...              ...             ...              ...     ...
# 840      4     63                1              28                7       4
# 841      5     76                1              28                7       4
# 842      2     37                4              28                7       4
# 843      5     76                1              29                7       4
# 844      8     61                4              30                0       4
#
# ...

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.20,random_state=2)

# %%
X_train
# Out:
#      brand  model  processor_brand  processor_Name  processor_gnrtn  ram_gb  \
# 131      6     58                4               6                0       2
# 200     17     78                4               7                1       2
# 176      4     63                4               6                1       2
# 128      2     83                1               6                7       2
# 195      8     61                4               7                1       2
# ..     ...    ...              ...             ...              ...     ...
# 542      5     72                4               8                1       2
# 592      8     61                4              31                1       2
# 501     10     70                4               8                0       2
# 535      8     61                1               8                7       2
# 170      8     61                4               6                0       2
#
# ...

# %%
X_test
# Out:
#      brand  model  processor_brand  processor_Name  processor_gnrtn  ram_gb  \
# 548      2     29                4               8                0       2
# 65       1      6                2               6                7       0
# 394      2    112                4               7                1       2
# 631      4     63                4              20                1       4
# 37      10     49                4               6                0       0
# ..     ...    ...              ...             ...              ...     ...
# 532     16     36                1               8                7       2
# 711      5     76                4              26                1       4
# 444     10     79                4               7                0       2
# 324      8     29                4               7                0       2
# 528      2    104                4               8                1       2
#
# ...

# %% [markdown]
# ### Model Preparation

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Accuracy

# %%
model.score(X_test,y_test)
# Out:
# 0.5066927955589831

# %% [markdown]
# ### cross_val_score function

# %%
from sklearn.model_selection import cross_val_score
cvmodel=cross_val_score(LinearRegression(), X, y,cv=5)
cvmodel
# Out:
# array([ 0.16797507,  0.47169288,  0.49008634,  0.52909745, -0.48818192])

# %% [markdown]
# ### Cval Accuracy

# %%
cvmodel.mean()
# Out:
# 0.23413396588964144
